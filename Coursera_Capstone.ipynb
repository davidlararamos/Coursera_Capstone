# %% [markdown]
# # Instructions

# %% [markdown]
# <br> 1. Write some markdown to explain that this notebook will be mainly used for the capstone project.
# <br> 2. Import the pandas library as pd.
# <br> 3. Import the Numpy library as np.
# <br> 4. Print the following the statement: Hello Capstone Project Course!

# %%
import pandas as pd
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
